# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvarajrcitchennai/DAA-LAB-EXPERIMENT-1/blob/main/2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# KMP Algorithm - Trace LPS Array and Shifts

def compute_lps(pattern):
    m = len(pattern)
    lps = [0] * m
    length = 0
    i = 1

    while i < m:
        if pattern[i] == pattern[length]:
            length += 1
            lps[i] = length
            i += 1
        else:
            if length != 0:
                length = lps[length - 1]
            else:
                lps[i] = 0
                i += 1

    return lps


def kmp_trace(text, pattern):
    n = len(text)
    m = len(pattern)

    lps = compute_lps(pattern)

    print("Text    :", text)
    print("Pattern :", pattern)
    print("\nLPS Array:", lps)

    i = 0
    j = 0

    print("\nTracing KMP Steps:")
    print("-" * 50)

    while i < n:
        print(f"Text[{i}] = {text[i]}, Pattern[{j}] = {pattern[j]}")

        if text[i] == pattern[j]:
            i += 1
            j += 1

            if j == m:
                print(f"\nPattern found at index {i - j}")
                j = lps[j - 1]

        else:
            if j != 0:
                print(f"Mismatch -> Shift using LPS[{j-1}] = {lps[j-1]}")
                j = lps[j - 1]
            else:
                print("Mismatch -> Move to next character")
                i += 1


# Main Program
text = "AABCAABXAAAZ"
pattern = "AABXAA"

kmp_trace(text, pattern)
# Out:
# Text    : AABCAABXAAAZ
# Pattern : AABXAA
#
# LPS Array: [0, 1, 0, 0, 1, 2]
#
# Tracing KMP Steps:
# --------------------------------------------------
# Text[0] = A, Pattern[0] = A
# Text[1] = A, Pattern[1] = A
# Text[2] = B, Pattern[2] = B
# Text[3] = C, Pattern[3] = X
# Mismatch -> Shift using LPS[2] = 0
# Text[3] = C, Pattern[0] = A
# Mismatch -> Move to next character
# Text[4] = A, Pattern[0] = A
# Text[5] = A, Pattern[1] = A
# Text[6] = B, Pattern[2] = B
# Text[7] = X, Pattern[3] = X
# Text[8] = A, Pattern[4] = A
# Text[9] = A, Pattern[5] = A
#
# Pattern found at index 4
# Text[10] = A, Pattern[2] = B
# Mismatch -> Shift using LPS[1] = 1
# Text[10] = A, Pattern[1] = A
# Text[11] = Z, Pattern[2] = B
# Mismatch -> Shift using LPS[1] = 1
# Text[11] = Z, Pattern[1] = A
# Mismatch -> Shift using LPS[0] = 0
# Text[11] = Z, Pattern[0] = A
# Mismatch -> Move to next character
