# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvarajrcitchennai/DAA-LAB-EXPERIMENT-1/blob/main/5C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Partition Function
def partition(arr, low, high):
    pivot = arr[high]
    i = low

    for j in range(low, high):
        if arr[j] <= pivot:
            arr[i], arr[j] = arr[j], arr[i]
            i += 1

    arr[i], arr[high] = arr[high], arr[i]
    return i


# QuickSelect Function
def quick_select(arr, low, high, k):
    if low <= high:
        pivot_index = partition(arr, low, high)

        if pivot_index == k:
            return arr[pivot_index]
        elif pivot_index > k:
            return quick_select(arr, low, pivot_index - 1, k)
        else:
            return quick_select(arr, pivot_index + 1, high, k)

    return None


# ---------------- Main Program ----------------

n = 1000

# Generate 1000 random integers
arr = [random.randint(1, 10000) for _ in range(n)]

# Test values
tests = [
    ("Minimum (k=1)", 1),
    ("Median (k=n//2)", n // 2),
    ("Maximum (k=n)", n)
]

for name, k in tests:
    result = quick_select(arr.copy(), 0, n - 1, k - 1)  # 0-based index
    print(f"{name}: {result}")
# Out:
# Minimum (k=1): 11
# Median (k=n//2): 4749
# Maximum (k=n): 9991
