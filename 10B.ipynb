# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvarajrcitchennai/DAA-LAB-EXPERIMENT-1/blob/main/10B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
import sys

sys.setrecursionlimit(30000)

comparisons = 0


# -------------------------------------------------
# Partition Function
# -------------------------------------------------
def partition(arr, low, high):
    global comparisons

    pivot = arr[high]
    i = low - 1

    for j in range(low, high):
        comparisons += 1

        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]

    return i + 1


# -------------------------------------------------
# Deterministic Quick Sort
# -------------------------------------------------
def deterministic_quicksort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        deterministic_quicksort(arr, low, pi - 1)
        deterministic_quicksort(arr, pi + 1, high)


# -------------------------------------------------
# Randomized Quick Sort
# -------------------------------------------------
def randomized_quicksort(arr, low, high):
    if low < high:

        rand_idx = random.randint(low, high)
        arr[rand_idx], arr[high] = arr[high], arr[rand_idx]

        pi = partition(arr, low, high)

        randomized_quicksort(arr, low, pi - 1)
        randomized_quicksort(arr, pi + 1, high)


# -------------------------------------------------
# Median of Three Pivot
# -------------------------------------------------
def median_of_three(arr, low, high):
    mid = (low + high) // 2

    a = arr[low]
    b = arr[mid]
    c = arr[high]

    if (a <= b <= c) or (c <= b <= a):
        return mid
    elif (b <= a <= c) or (c <= a <= b):
        return low
    else:
        return high


# -------------------------------------------------
# Median-of-Three Quick Sort
# -------------------------------------------------
def median_quicksort(arr, low, high):
    if low < high:

        pivot_idx = median_of_three(arr, low, high)

        arr[pivot_idx], arr[high] = arr[high], arr[pivot_idx]

        pi = partition(arr, low, high)

        median_quicksort(arr, low, pi - 1)
        median_quicksort(arr, pi + 1, high)


# -------------------------------------------------
# Test Runner
# -------------------------------------------------
def run_test(sort_fn, arr):
    global comparisons

    a = arr[:]
    comparisons = 0

    start = time.perf_counter()

    sort_fn(a, 0, len(a) - 1)

    elapsed = (time.perf_counter() - start) * 1000

    return comparisons, elapsed


# -------------------------------------------------
# Input Arrays
# -------------------------------------------------
N = 10000

test_cases = {
    "Random": [random.randint(1, 100000) for _ in range(N)],
    "Sorted": list(range(N)),
    "Reverse": list(range(N, 0, -1))
}

print("-" * 110)
print(
    f'{"Input":<12}'
    f'{"DQS Comp":>14}'
    f'{"RQS Comp":>14}'
    f'{"M3QS Comp":>16}'
)
print("-" * 110)

for case, arr in test_cases.items():

    d_comp, _ = run_test(deterministic_quicksort, arr)

    r_comp, _ = run_test(randomized_quicksort, arr)

    m_comp, _ = run_test(median_quicksort, arr)

    print(
        f'{case:<12}'
        f'{d_comp:>14}'
        f'{r_comp:>14}'
        f'{m_comp:>16}'
    )
# Out:
# --------------------------------------------------------------------------------------------------------------
# Input             DQS Comp      RQS Comp       M3QS Comp
# --------------------------------------------------------------------------------------------------------------
# Random              155873        149426          130949
# Sorted            49995000        154975          113631
# Reverse           49995000        155903          225614
